# %%
from IPython.display import clear_output

# 1. Build a Shopping Cart

# Ask the user four bits of input: Do you want to : Show/Add/Delete or Quit?

print("*Welcome to shopping cart by python*\n")

# Creating dictionary for shopping cart and index variable
shop_cart = {}
p = {}
i = 0
item = input("Enter an item: ")
shop_cart[i+1] = item
i += 1

# While loop keeps program returning to first question until user quits
while True:
    ans = input("Would you like to:\n\t's' - Show current shopping list?\n\t'a' - Add to shopping list?\n\t'd' - Delete an item?\n\t'q' - Quit?\n ")
    if ans == "s":
        print(shop_cart)
        continue
    elif ans == "d":
        print(shop_cart)
        while True:
            item_del = input("Enter the item number you would you like to delete ('q' to go back): ")
            if item_del == "q":
                break
            else: 
                try:
                    del(shop_cart[int(item_del)])
#                     >try searching for any higher # keys in cart and reducing by 1. Not working perfectly  
#                     >Method 1: doesn't work when more than one item ahead of deleted item
#                     for k, v in shop_cart.items():
#                         elif k > int(item_del):
#                             del shop_cart[k]
#                             shop_cart[k-1] = v
                    
#                     >Method 2: didn't work when deleting middle items
#                     if k < int(item_del):
#                             p[k] = v
#                         elif k > int(item_del):
#                             p[k-1] = v
#                     shop_cart = p
                    
                    print("\nWould you like to delete another item?")
                except:
                    print("Please enter valid input")
        continue
    elif ans == "a":
        item = input("Enter an item: ")
        shop_cart[i+1] = item
        i += 1
        continue
    elif ans == "q":
        break
    break
# Out:
# *Welcome to shopping cart by python*
#
# Enter an item: eggs
# Would you like to:
# 	's' - Show current shopping list?
# 	'a' - Add to shopping list?
# 	'd' - Delete an item?
# 	'q' - Quit?
#  a
# Enter an item: bacon
# Would you like to:
# 	's' - Show current shopping list?
# 	'a' - Add to shopping list?
# 	'd' - Delete an item?
# 	'q' - Quit?
#  a
# Enter an item: milk
# Would you like to:
# 	's' - Show current shopping list?
# 	'a' - Add to shopping list?
# 	'd' - Delete an item?
# 	'q' - Quit?
#  a
# Enter an item: chicken
# Would you like to:
# 	's' - Show current shopping list?
# 	'a' - Add to shopping list?
# 	'd' - Delete an item?
# 	'q' - Quit?
#  d
# {1: 'eggs', 2: 'bacon', 3: 'milk', 4: 'chicken'}
# Enter the item number you would you like to delete ('q' to go back): 1
#
# Would you like to delete another item?
# Enter the item number you would you like to delete ('q' to go back): q
# Would you like to:
# 	's' - Show current shopping list?
# 	'a' - Add to shopping list?
# 	'd' - Delete an item?
# 	'q' - Quit?
#  s
# {2: 'bacon', 3: 'milk', 4: 'chicken'}
# Would you like to:
# 	's' - Show current shopping list?
# 	'a' - Add to shopping list?
# 	'd' - Delete an item?
# 	'q' - Quit?
#  q

# %%
# 2. Create a Module in VS Code and Import It into jupyter notebook

import test_module

print(test_module.find_area(5, 3))

print(test_module.find_circ(4))
# Out:
# 15
# 25.132741228718345
